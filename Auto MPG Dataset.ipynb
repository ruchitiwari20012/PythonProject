# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Auto-mdg.csv')

# %%
df
# Out:
#       mdg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 401  27.0          4         140.0        86.0    2790          15.6
# 402  44.0          4          97.0        52.0    2130          24.6
# 403  32.0          4         135.0        84.0    2295          11.6
# 404  28.0          4         120.0        79.0    2625          18.6
# 405  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin                       car name
# 0            70     1.0  \t"chevrolet chevelle malibu"
# ...

# %%
df.head()
# Out:
#     mdg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model year  origin                       car name
# 0          70     1.0  \t"chevrolet chevelle malibu"
# 1          70     1.0          \t"buick skylark 320"
# 2          70     1.0         \t"plymouth satellite"
# 3          70     1.0              \t"amc rebel sst"
# 4          70     1.0                \t"ford torino"

# %%
df.tail()
# Out:
#       mdg  cylinders  displacement  horsepower  weight  acceleration  \
# 401  27.0          4         140.0        86.0    2790          15.6
# 402  44.0          4          97.0        52.0    2130          24.6
# 403  32.0          4         135.0        84.0    2295          11.6
# 404  28.0          4         120.0        79.0    2625          18.6
# 405  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin             car name
# 401          82     1.0  \t"ford mustang gl"
# 402          82     2.0        \t"vw pickup"
# 403          82     1.0    \t"dodge rampage"
# 404          82     1.0      \t"ford ranger"
# 405          82     1.0       \t"chevy s-10"

# %%
df.shape
# Out:
# (406, 9)

# %%
df.columns
# Out:
# Index(['mdg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
df.dtypes
# Out:
# mdg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin          float64
# car name         object
# dtype: object

# %%
df.isnull().sum()
# Out:
# mdg             8
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
data=df.replace(np.NaN,0)

# %%
data.isnull().sum()
# Out:
# mdg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mdg           406 non-null    float64
#  1   cylinders     406 non-null    int64
#  2   displacement  406 non-null    float64
#  3   horsepower    406 non-null    float64
#  4   weight        406 non-null    int64
#  5   acceleration  406 non-null    float64
#  6   model year    406 non-null    int64
#  7   origin        406 non-null    float64
#  8   car name      406 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.7+ KB

# %%
sns.heatmap(data.isnull())

# %%
data.describe()
# Out:
#               mdg   cylinders  displacement  horsepower       weight  \
# count  406.000000  406.000000    406.000000  406.000000   406.000000
# mean    23.051232    5.475369    194.779557  103.529557  2979.413793
# std      8.401777    1.712160    104.922458   40.520659   847.004328
# min      0.000000    3.000000     68.000000    0.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2226.500000
# 50%     22.350000    4.000000    151.000000   93.500000  2822.500000
# 75%     29.000000    8.000000    302.000000  129.000000  3618.250000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model year      origin
# count    406.000000  406.000000  406.000000
# mean      15.519704   75.921182    1.568966
# std        2.803359    3.748737    0.797479
# min        8.000000   70.000000    1.000000
# 25%       13.700000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
datacor=data.corr()
datacor
# Out:
#                    mdg  cylinders  displacement  horsepower    weight  \
# mdg           1.000000  -0.735563     -0.764277   -0.726670 -0.787510
# cylinders    -0.735563   1.000000      0.951787    0.823467  0.895220
# displacement -0.764277   0.951787      1.000000    0.873758  0.932475
# horsepower   -0.726670   0.823467      0.873758    1.000000  0.840811
# weight       -0.787510   0.895220      0.932475    0.840811  1.000000
# acceleration  0.424490  -0.522452     -0.557984   -0.682047 -0.430086
# model year    0.586234  -0.360762     -0.381714   -0.419929 -0.315389
# origin        0.530206  -0.567478     -0.613056   -0.424100 -0.584109
#
#               acceleration  model year    origin
# mdg               0.424490    0.586234  0.530206
# cylinders        -0.522452   -0.360762 -0.567478
# displacement     -0.557984   -0.381714 -0.613056
# horsepower       -0.682047   -0.419929 -0.424100
# weight           -0.430086   -0.315389 -0.584109
# ...

# %%
sns.heatmap(datacor)

# %% [markdown]
#  The column cylinders ,displacement, horsepower and weight are positive correlated with each other.
#  The mdg column are little bit correlated with the origin ,model year and acceleration

# %%
sns.violinplot(x='mdg',data=data)
plt.show()

# %%
sns.distplot(data['mdg'],bins=20)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['car name']=le.fit_transform(data['car name'])

# %%
data.skew()
# Out:
# mdg             0.091913
# cylinders       0.506356
# displacement    0.694130
# horsepower      0.748130
# weight          0.505684
# acceleration    0.230224
# model year      0.020912
# origin          0.932399
# car name        0.025420
# dtype: float64

# %%
import numpy as np
for col in data.columns:
    if data.skew().loc[col]>0.55:
        data[col]=np.log1p(data[col])

# %%
data.skew()
# Out:
# mdg             0.091913
# cylinders       0.506356
# displacement    0.215796
# horsepower     -4.874268
# weight          0.505684
# acceleration    0.230224
# model year      0.020912
# origin          0.801503
# car name        0.025420
# dtype: float64

# %%
data.drop(['car name'],axis = 1)
# Out:
#       mdg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8      5.730100    4.875197    3504          12.0
# 1    15.0          8      5.860786    5.111988    3693          11.5
# 2    18.0          8      5.765191    5.017280    3436          11.0
# 3    16.0          8      5.720312    5.017280    3433          12.0
# 4    17.0          8      5.713733    4.948760    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 401  27.0          4      4.948760    4.465908    2790          15.6
# 402  44.0          4      4.584967    3.970292    2130          24.6
# 403  32.0          4      4.912655    4.442651    2295          11.6
# 404  28.0          4      4.795791    4.382027    2625          18.6
# 405  31.0          4      4.787492    4.418841    2720          19.4
#
#      model year    origin
# 0            70  0.693147
# 1            70  0.693147
# 2            70  0.693147
# 3            70  0.693147
# ...

# %%
data
# Out:
#       mdg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8      5.730100    4.875197    3504          12.0
# 1    15.0          8      5.860786    5.111988    3693          11.5
# 2    18.0          8      5.765191    5.017280    3436          11.0
# 3    16.0          8      5.720312    5.017280    3433          12.0
# 4    17.0          8      5.713733    4.948760    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 401  27.0          4      4.948760    4.465908    2790          15.6
# 402  44.0          4      4.584967    3.970292    2130          24.6
# 403  32.0          4      4.912655    4.442651    2295          11.6
# 404  28.0          4      4.795791    4.382027    2625          18.6
# 405  31.0          4      4.787492    4.418841    2720          19.4
#
#      model year    origin  car name
# 0            70  0.693147        51
# 1            70  0.693147        36
# ...

# %%
data['mdg'].plot.box()

# %%
data['horsepower'].plot.box()

# %%
from scipy.stats import zscore
zscore=abs(zscore(data))
print(data.shape)
# Out:
# (406, 9)

# %%
df.hist(figsize=(9,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000008B69B61C88>,
# ...
#       dtype=object)

# %%
threshold=3
print(np.where(zscore>3))
# Out:
# (array([ 38, 133, 306, 337, 343, 361, 382, 402], dtype=int64), array([3, 3, 5, 3, 3, 3, 3, 5], dtype=int64))

# %%
data_new=data[(zscore<3).all(axis=1)]

# %%
data.shape
# Out:
# (406, 9)

# %%
data_new.shape
# Out:
# (398, 9)

# %%
#8 rows got deleted as outlier was present in the dataset

# %%
sns.pairplot(data_new)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(data_new)
x=pd.DataFrame(x,columns=data_new.columns)

# %%
x
# Out:
#           mdg  cylinders  displacement  horsepower    weight  acceleration  \
# 0   -0.589325   1.457171      1.105506    0.787907  0.607274     -1.262019
# 1   -0.949140   1.457171      1.351466    1.481102  0.829795     -1.445107
# 2   -0.589325   1.457171      1.171550    1.203848  0.527214     -1.628195
# 3   -0.829202   1.457171      1.087084    1.203848  0.523682     -1.262019
# 4   -0.709263   1.457171      1.074702    1.003259  0.542519     -1.811283
# ..        ...        ...           ...         ...       ...           ...
# 393  0.490120  -0.874302     -0.223648   -0.278677 -0.044982      0.678714
# 394  0.490120  -0.874302     -0.365030   -0.410270 -0.233359      0.056214
# 395  1.089811  -0.874302     -0.432982   -0.478354 -0.816152     -1.408489
# 396  0.610058  -0.874302     -0.652929   -0.655830 -0.427624      1.154742
# 397  0.969873  -0.874302     -0.668548   -0.548059 -0.315775      1.447683
#
#      model year    origin  car name
# ...

# %%
y=data_new.iloc[:,0].values

# %%
y
# Out:
# array([18. , 15. , 18. , 16. , 17. , 15. , 14. , 14. , 14. , 15. ,  0. ,
#         0. ,  0. ,  0. ,  0. , 15. , 14. ,  0. , 15. , 14. , 24. , 22. ,
#        18. , 21. , 27. , 26. , 25. , 24. , 25. , 26. , 21. , 10. , 10. ,
#        11. ,  9. , 27. , 28. , 25. ,  0. , 19. , 16. , 17. , 19. , 18. ,
#        14. , 14. , 14. , 14. , 12. , 13. , 13. , 18. , 22. , 19. , 18. ,
#        23. , 28. , 30. , 30. , 31. , 35. , 27. , 26. , 24. , 25. , 23. ,
#        20. , 21. , 13. , 14. , 15. , 14. , 17. , 11. , 13. , 12. , 13. ,
#        19. , 15. , 13. , 13. , 14. , 18. , 22. , 21. , 26. , 22. , 28. ,
#        23. , 28. , 27. , 13. , 14. , 13. , 14. , 15. , 12. , 13. , 13. ,
#        14. , 13. , 12. , 13. , 18. , 16. , 18. , 18. , 23. , 26. , 11. ,
#        12. , 13. , 12. , 18. , 20. , 21. , 22. , 18. , 19. , 21. , 26. ,
#        15. , 16. , 29. , 24. , 20. , 19. , 15. , 24. , 20. , 11. , 20. ,
#        19. , 15. , 31. , 26. , 32. , 25. , 16. , 16. , 18. , 16. , 13. ,
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(y)
y
# Out:
# array([ 18,   8,  18,  10,  14,   8,   6,   6,   6,   8,   0,   0,   0,
#          0,   0,   8,   6,   0,   8,   6,  49,  39,  18,  35,  63,  58,
#         53,  49,  53,  58,  35,   2,   2,   3,   1,  63,  68,  53,   0,
#         23,  10,  14,  23,  18,   6,   6,   6,   6,   4,   5,   5,  18,
#         39,  23,  18,  43,  68,  76,  76,  80, 105,  63,  58,  49,  53,
#         43,  29,  35,   5,   6,   8,   6,  14,   3,   5,   4,   5,  23,
#          8,   5,   5,   6,  18,  39,  35,  58,  39,  68,  43,  68,  63,
#          5,   6,   5,   6,   8,   4,   5,   5,   6,   5,   4,   5,  18,
#         10,  18,  18,  43,  58,   3,   4,   5,   4,  18,  29,  35,  39,
#         18,  23,  35,  58,   8,  10,  72,  49,  29,  23,   8,  49,  29,
#          3,  29,  23,   8,  80,  58,  86,  53,  10,  10,  18,  10,   5,
#          6,   6,   6,  72,  58,  58,  80,  86,  68,  49,  58,  49,  58,
#         80,  23,  18,   8,   8,  10,   8,  10,   6,  14,  10,   8,  18,
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split (x, y,random_state = 55,test_size=0.20)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
max_r_score=0
for r_state in range(42,100):
    x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = r_state,test_size=0.20)
    regr= linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred = regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
# Out:
# max r2 score corresponding to  57  is  0.9779300640243294

# %%
# Lets perform the cross_validation 
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression() ,x,y,cv=5,scoring='r2').mean()
#it will calculate the 5 score and find the mean of that
# Out:
# 0.8462406322149836

# %%
#since maximum r2 score is comming around random state 57 we will use that to create our final model
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=57,test_size=0.20)
lr=linear_model.LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
import numpy as np
print('r2 score is: ',r2_score(y_test,y_pred))
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score is:  0.9779300640243294
# RMSE is:  5.144451809919618

# %%
from sklearn.externals import joblib
# Save the model as a pickle in a file 
joblib.dump(lr,'lr_AutoMPG.pkl')
# Out:
# ['lr_AutoMPG.pkl']
