# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('LoanDataset')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#Their is null value present in the dataset.

# %%
#df.replace(np.NaN,mean)
df.replace(np.NaN,df.mean,inplace=True)

# %%
# In above i have changed the NaN with 0
#Again I am checking that is their any null value

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount            object
# Loan_Amount_Term      object
# Credit_History        object
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount            object
# Loan_Amount_Term      object
# Credit_History        object
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
#I am droping the 3 columns i try to convert but unable by applying the both method of change datatype and label encoder

# %%
df.drop(['Dependents'], axis = 1) 
df.drop(['Married'],axis = 1)
df.drop(['Gender'],axis = 1)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     403                         if cls is not object \
#     404                                 and callable(cls.__dict__.get('__repr__')):
# --> 405                             return _repr_pprint(obj, self, cycle)
#     406
#     407             return _default_pprint(obj, self, cycle)
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df[ 'Loan_Status']=le.fit_transform(df['Loan_Status' ])
df['Property_Area']=le.fit_transform(df['Property_Area'])
df['Education']=le.fit_transform(df['Education'])
df['Loan_ID']=le.fit_transform(df['Loan_ID'])

# %%
sns.heatmap(df.isnull())

# %%
df.describe()
# Out:
#           Loan_ID   Education  ApplicantIncome  CoapplicantIncome  \
# count  614.000000  614.000000       614.000000         614.000000
# mean   306.500000    0.218241      5403.459283        1621.245798
# std    177.390811    0.413389      6109.041673        2926.248369
# min      0.000000    0.000000       150.000000           0.000000
# 25%    153.250000    0.000000      2877.500000           0.000000
# 50%    306.500000    0.000000      3812.500000        1188.500000
# 75%    459.750000    0.000000      5795.000000        2297.250000
# max    613.000000    1.000000     81000.000000       41667.000000
#
#        Property_Area  Loan_Status
# count     614.000000   614.000000
# mean        1.037459     0.687296
# std         0.787482     0.463973
# min         0.000000     0.000000
# 25%         0.000000     0.000000
# 50%         1.000000     1.000000
# 75%         2.000000     1.000000
# max         2.000000     1.000000

# %%
dfcor=df.corr()
dfcor
# Out:
#                     Loan_ID  Education  ApplicantIncome  CoapplicantIncome  \
# Loan_ID            1.000000   0.039442         0.016925           0.039211
# Education          0.039442   1.000000        -0.140760          -0.062290
# ApplicantIncome    0.016925  -0.140760         1.000000          -0.116605
# CoapplicantIncome  0.039211  -0.062290        -0.116605           1.000000
# Property_Area     -0.155416  -0.065243        -0.009500           0.010522
# Loan_Status        0.011773  -0.085884        -0.004710          -0.059187
#
#                    Property_Area  Loan_Status
# Loan_ID                -0.155416     0.011773
# Education              -0.065243    -0.085884
# ApplicantIncome        -0.009500    -0.004710
# CoapplicantIncome       0.010522    -0.059187
# Property_Area           1.000000     0.032112
# Loan_Status             0.032112     1.000000

# %%
sns.heatmap(dfcor)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Dependents']=le.fit_transform(df['Dependents'])
df['Married']=le.fit_transform(df['Married'])
df['Gender']=le.fit_transform(df['Gender'])
df['Self_Employed']=le.fit_transform(df['Self_Employed'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode(values, uniques, encode, check_unknown)
#     111         try:
# --> 112             res = _encode_python(values, uniques, encode)
#     113         except TypeError:
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode_python(values, uniques, encode)
#      59     if uniques is None:
# ---> 60         uniques = sorted(set(values))
#      61         uniques = np.array(uniques, dtype=values.dtype)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1798         raise TypeError(
# -> 1799             f"{repr(type(self).__name__)} objects are mutable, "
#    1800             f"thus they cannot be hashed"
#
# TypeError: 'DataFrame' objects are mutable, thus they cannot be hashed
#
# ...

# %%
dft=pd.DataFrame(df)

# %%
dft
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     403                         if cls is not object \
#     404                                 and callable(cls.__dict__.get('__repr__')):
# --> 405                             return _repr_pprint(obj, self, cycle)
#     406
#     407             return _default_pprint(obj, self, cycle)
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %%
#dft.drop(, axis = 1, inplace = True)

# %%
dft.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
dft.skew()
# Out:
# Loan_ID              0.000000
# Education            1.367622
# ApplicantIncome      6.539513
# CoapplicantIncome    7.491531
# Property_Area       -0.066196
# Loan_Status         -0.809998
# dtype: float64

# %%
skew = ('Loan_ID','Education','ApplicantIncome','CoapplicantIncome','Property_Area','Loan_Status')

# %%
for col in skew:
    if dft.skew().loc[col]>0.55:
        dft[col]=np.log1p(dft[col])

# %%
dft.skew()
# Out:
# Loan_ID              0.000000
# Education            1.367622
# ApplicantIncome      0.482128
# CoapplicantIncome   -0.173073
# Property_Area       -0.066196
# Loan_Status         -0.809998
# dtype: float64

# %%
sns.pairplot(dft)

# %%
dft.drop(['Gender'], axis = 1)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(dft)
x=pd.DataFrame(x,columns=dft.columns)

# %% [markdown]
# I Try a resolve the issue but i am not able to work further, since i try to change the datatype and drop to the particular columns and
# apply the labelencoder but is was not run. I am unable to work further on this dataset
