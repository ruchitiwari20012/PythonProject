# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('space')

# %%
df
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# ...

# %%
df.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
# 3  15.90438  752    301       4    269  3.722370e+18    STAR -0.000111   3306
# 4  16.61326  752    301       4    269  3.722370e+18    STAR  0.000590   3306
#
#      mjd  fiberid
# ...

# %%
df.shape
# Out:
# (10000, 18)

# %%
df.columns
# Out:
# Index(['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol',
#        'field', 'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid'],
#       dtype='object')

# %%
df.dtypes
# Out:
# objid        float64
# ra           float64
# dec          float64
# u            float64
# g            float64
# r            float64
# i            float64
# z            float64
# run            int64
# rerun          int64
# camcol         int64
# field          int64
# specobjid    float64
# class         object
# redshift     float64
# plate          int64
# mjd            int64
# fiberid        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# objid        0
# ra           0
# dec          0
# u            0
# g            0
# r            0
# i            0
# z            0
# run          0
# rerun        0
# camcol       0
# field        0
# specobjid    0
# class        0
# redshift     0
# plate        0
# mjd          0
# fiberid      0
# dtype: int64

# %% [markdown]
# No null values are present in the dataset

# %%
#ds=df.replace(np.NaN,mean)
df.replace(np.NaN,df.mean,inplace=True)

# %%
df.describe()
# Out:
#               objid            ra           dec             u             g  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000  10000.000000
# mean   1.237650e+18    175.529987     14.836148     18.619355     17.371931
# std    1.577039e+05     47.783439     25.212207      0.828656      0.945457
# min    1.237650e+18      8.235100     -5.382632     12.988970     12.799550
# 25%    1.237650e+18    157.370946     -0.539035     18.178035     16.815100
# 50%    1.237650e+18    180.394514      0.404166     18.853095     17.495135
# 75%    1.237650e+18    201.547279     35.649397     19.259232     18.010145
# max    1.237650e+18    260.884382     68.542265     19.599900     19.918970
#
#                   r             i             z           run    rerun  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.0
# mean      16.840963     16.583579     16.422833    981.034800    301.0
# ...

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# I applyed label encoder for the class

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['class']=le.fit_transform(df['class'])

# %%
dfcor=df.corr()
dfcor
# Out:
#                   objid            ra           dec             u  \
# objid      1.000000e+00  2.524419e-14 -1.937483e-15  5.581214e-14
# ra         2.524419e-14  1.000000e+00  3.596046e-03  3.123756e-02
# dec       -1.937483e-15  3.596046e-03  1.000000e+00  3.527932e-02
# u          5.581214e-14  3.123756e-02  3.527932e-02  1.000000e+00
# g          1.001149e-13  4.390863e-02  6.187471e-02  8.492320e-01
# r          2.995673e-14  4.710290e-02  6.340395e-02  6.923790e-01
# i          2.212198e-14  4.573107e-02  5.829189e-02  6.026302e-01
# z         -4.107700e-14  4.294957e-02  5.687030e-02  5.514828e-01
# run       -1.553011e-14 -9.274056e-02  7.783849e-01  3.822910e-02
# rerun               NaN           NaN           NaN           NaN
# camcol     1.921887e-15 -6.293831e-03  1.146139e-01  9.944672e-03
# field      5.938881e-16  5.946996e-01 -1.314714e-01  8.547880e-03
# specobjid -1.829075e-15 -9.532711e-02  8.834533e-02 -1.294293e-01
# ...

# %%
sns.heatmap(dfcor)

# %% [raw]
# The u g r i and z columns are highly correlated
# the plate and mjd botha are very hight correlated
# specobjid are highly correlated with plate and mjd
# redshift are little bit correlated with g r i and z

# %%
df.skew()
# Out:
# objid        1.000150
# ra          -1.227350
# dec          1.191544
# u           -1.219795
# g           -0.536293
# r           -0.021673
# i            0.286442
# z            0.214313
# run          0.412555
# rerun        0.000000
# camcol      -0.100220
# field        0.249795
# specobjid    1.794627
# class        0.169292
# redshift     4.265729
# plate        1.794609
# mjd          1.039610
# fiberid      0.308053
# dtype: float64

# %% [markdown]
# Their is no skewness in the dataset

# %%
df['ra'].plot.box()

# %%
#from scipy.stats import zscore
#z=np.abs(zscore(ds))
#z

from scipy.stats import zscore
zscore=abs(zscore(df))
print(df.shape)
# Out:
# (10000, 18)

# %%
threshold=3
print(np.where(zscore>3))
# Out:
# (array([  45,  109,  129, ..., 9994, 9997, 9997], dtype=int64), array([14, 14, 14, ..., 15, 12, 15], dtype=int64))

# %%
df_new=df[(zscore>3).all(axis=1)]

# %%
df.shape
# Out:
# (10000, 18)

# %%
df_new.shape
# Out:
# (0, 18)

# %%
df.dropna(inplace=True)
df
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid  class  \
# ...

# %%
#I dont Know the reason why i am getting this df_new value 0  so i am continue to apply on df data for futher work

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df)
x=pd.DataFrame(x,columns=df.columns)

# %%
x
# Out:
#       objid        ra       dec         u         g         r         i  \
# 0       0.0  0.167458 -0.584923  1.031486 -0.348559 -0.837280 -0.946058
# 1       0.0  0.168862 -0.583114  0.052430 -0.166533 -0.154155 -0.082645
# 2       0.0  0.170574 -0.583475  0.921568  0.867093  0.593154  0.441201
# 3       0.0  0.174558 -0.586501 -1.030630 -0.813627 -0.636692 -0.526604
# 4       0.0  0.174825 -0.584412 -1.290232 -1.172519 -0.376762 -0.025101
# ...     ...       ...       ...       ...       ...       ...       ...
# 9995    0.0 -0.925337  1.455852  0.239453  0.104292  0.069416  0.087121
# 9996    0.0 -0.925553  1.461079 -0.418536  0.070402  0.220993  0.116515
# 9997    0.0 -0.920395  1.460907  0.167538  0.429347  0.634775  0.743983
# 9998    0.0 -0.921973  1.464321  0.318018  0.569857  0.646764  0.682516
# 9999    0.0 -0.918041  1.466393  0.792292  0.006726 -0.501581 -0.655223
#
#              z       run  rerun    camcol     field  specobjid     class  \
# ...

# %%
x.drop('rerun', axis = 1, inplace = True)

# %%
y=df.iloc[:,-5]
y.head()
# Out:
# 0    2
# 1    2
# 2    0
# 3    2
# 4    2
# Name: class, dtype: int32

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(y)
y
# Out:
# array([2, 2, 0, ..., 2, 0, 0], dtype=int64)

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=9,stratify=y)

# %%
print(x_train.shape,x_test.shape)
# Out:
# (7000, 17) (3000, 17)

# %%
print(y_train.shape,y_test.shape)
# Out:
# (7000,) (3000,)

# %%
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
model=[GaussianNB(),SVC(),DecisionTreeClassifier()]

# %%
for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print('accuracy score of',m,'is:')
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')
# Out:
# accuracy score of GaussianNB(priors=None, var_smoothing=1e-09) is:
# 1.0
# [[1499    0    0]
#  [   0  255    0]
#  [   0    0 1246]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1499
#            1       1.00      1.00      1.00       255
#            2       1.00      1.00      1.00      1246
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000
#
#
#
# accuracy score of SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False) is:
# 0.9993333333333333
# [[1498    1    0]
#  [   0  254    1]
#  [   0    0 1246]]
#               precision    recall  f1-score   support
#
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=[KNeighborsClassifier()]

# %%
for m in model:
    m.fit(x_train,y_train)
    predm=m.predict(x_test)
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')
# Out:
# 0.987
# [[1487    4    8]
#  [  17  229    9]
#  [   0    1 1245]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1499
#            1       0.98      0.90      0.94       255
#            2       0.99      1.00      0.99      1246
#
#     accuracy                           0.99      3000
#    macro avg       0.98      0.96      0.97      3000
# weighted avg       0.99      0.99      0.99      3000

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
# Out:
# 1.0

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100,random_state=42)
# 
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# 0.9996666666666667
# [[1499    0    0]
#  [   1  254    0]
#  [   0    0 1246]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1499
#            1       1.00      1.00      1.00       255
#            2       1.00      1.00      1.00      1246
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000

# %%
from sklearn.ensemble import AdaBoostClassifier
ad=AdaBoostClassifier()
ad.fit(x_train,y_train)
ad_pred=ad.predict(x_test)
print(accuracy_score(y_test,ad_pred))
print(confusion_matrix(y_test,ad_pred))
print(classification_report(y_test,ad_pred))
# Out:
# 1.0
# [[1499    0    0]
#  [   0  255    0]
#  [   0    0 1246]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1499
#            1       1.00      1.00      1.00       255
#            2       1.00      1.00      1.00      1246
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000

# %% [markdown]
#  from the above i have see the score of AdaBoostClassifier and the GaussianNB  model are performing well with score of 100
#     percent i am saving the model

# %%
from sklearn.externals import joblib

#save the model as a pickel in a file
joblib.dump(GaussianNB, "Space_GaussianNB.pkl")
# Out:
# ['Space_GaussianNB.pkl']
