# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

# %%
import pandas as pd
con=mysql.connector.connect(
    host="localhost",
    port=3306,
    user="root",
    password="Ruchi@1992",
    database="testdb")

df=pd.read_sql_query("select * from Wine",con)
df
df.head(10)
# Out:
#    Class  Alcohol  MalicAcid   Ash  Alcalinityofash  Magnesium  Totalphenols  \
# 0      0     0.00       0.00  0.00              0.0        0.0          0.00
# 1      1    14.23       1.71  2.43             15.6      127.0          2.80
# 2      1    13.20       1.78  2.14             11.2      100.0          2.65
# 3      1    13.16       2.36  2.67             18.6      101.0          2.80
# 4      1    14.37       1.95  2.50             16.8      113.0          3.85
# 5      1    13.24       2.59  2.87             21.0      118.0          2.80
# 6      1    14.20       1.76  2.45             15.2      112.0          3.27
# 7      1    14.39       1.87  2.45             14.6       96.0          2.50
# 8      1    14.06       2.15  2.61             17.6      121.0          2.60
# 9      1    14.83       1.64  2.17             14.0       97.0          2.80
#
#    Flavanoids  Nonflavanoidsphenols  Proanthocyanins  colorintensity   Hue  \
# ...

# %%
df.drop([0],inplace = True)

# %%
#since the 0 row have no data so i am droping it

# %%
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 178 entries, 1 to 178
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Class                 178 non-null    int64
#  1   Alcohol               178 non-null    float64
#  2   MalicAcid             178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Alcalinityofash       178 non-null    float64
#  5   Magnesium             178 non-null    float64
#  6   Totalphenols          178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoidsphenols  178 non-null    float64
#  9   Proanthocyanins       178 non-null    float64
#  10  colorintensity        178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  dilutedwines          178 non-null    float64
#  13  Proline               178 non-null    int64
# dtypes: float64(12), int64(2)
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
df.dtypes
# Out:
# Class                     int64
# Alcohol                 float64
# MalicAcid               float64
# Ash                     float64
# Alcalinityofash         float64
# Magnesium               float64
# Totalphenols            float64
# Flavanoids              float64
# Nonflavanoidsphenols    float64
# Proanthocyanins         float64
# colorintensity          float64
# Hue                     float64
# dilutedwines            float64
# Proline                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Class', 'Alcohol', 'MalicAcid', 'Ash', 'Alcalinityofash', 'Magnesium',
#        'Totalphenols', 'Flavanoids', 'Nonflavanoidsphenols', 'Proanthocyanins',
#        'colorintensity', 'Hue', 'dilutedwines', 'Proline'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Class     Alcohol   MalicAcid         Ash  Alcalinityofash  \
# count  178.000000  178.000000  178.000000  178.000000       178.000000
# mean     1.938202   13.000618    2.336348    2.366517        19.494944
# std      0.775035    0.811827    1.117146    0.274344         3.339564
# min      1.000000   11.030000    0.740000    1.360000        10.600000
# 25%      1.000000   12.362500    1.602500    2.210000        17.200000
# 50%      2.000000   13.050000    1.865000    2.360000        19.500000
# 75%      3.000000   13.677500    3.082500    2.557500        21.500000
# max      3.000000   14.830000    5.800000    3.230000        30.000000
#
#         Magnesium  Totalphenols  Flavanoids  Nonflavanoidsphenols  \
# count  178.000000    178.000000  178.000000            178.000000
# mean    99.741573      2.295112    2.029270              0.361854
# std     14.282484      0.625851    0.998859              0.124453
# ...

# %%
df.Class.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
df.Class.value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: Class, dtype: int64

# %%
df.isnull().sum()
# Out:
# Class                   0
# Alcohol                 0
# MalicAcid               0
# Ash                     0
# Alcalinityofash         0
# Magnesium               0
# Totalphenols            0
# Flavanoids              0
# Nonflavanoidsphenols    0
# Proanthocyanins         0
# colorintensity          0
# Hue                     0
# dilutedwines            0
# Proline                 0
# dtype: int64

# %%
# Their is no null value in the data

# %%
sns.heatmap(df.isnull())

# %%
dfcor=df.corr()
dfcor
# Out:
#                          Class   Alcohol  MalicAcid       Ash  \
# Class                 1.000000 -0.328222   0.437776 -0.049643
# Alcohol              -0.328222  1.000000   0.094397  0.211545
# MalicAcid             0.437776  0.094397   1.000000  0.164045
# Ash                  -0.049643  0.211545   0.164045  1.000000
# Alcalinityofash       0.517859 -0.310235   0.288500  0.443367
# Magnesium            -0.209179  0.270798  -0.054575  0.286587
# Totalphenols         -0.719163  0.289101  -0.335167  0.128980
# Flavanoids           -0.847498  0.236815  -0.411007  0.115077
# Nonflavanoidsphenols  0.489109 -0.155929   0.292977  0.186230
# Proanthocyanins      -0.499130  0.136698  -0.220746  0.009652
# colorintensity        0.265668  0.546364   0.248985  0.258887
# Hue                  -0.617369 -0.071747  -0.561296 -0.074667
# dilutedwines         -0.788230  0.072343  -0.368710  0.003911
# Proline              -0.633717  0.643720  -0.192011  0.223626
#
# ...

# %%
sns.heatmap(dfcor)

# %% [markdown]
# The Class column have a negative correlation with the Hue,dilutedwines,Proline,Proanthocyanins,Totalphenols and with Flavanoids
# Hue and dilutedwines have positive correlation.
# Totalphenols and Flavanoids have a positive correlation.

# %%
df.columns
# Out:
# Index(['Class', 'Alcohol', 'MalicAcid', 'Ash', 'Alcalinityofash', 'Magnesium',
#        'Totalphenols', 'Flavanoids', 'Nonflavanoidsphenols', 'Proanthocyanins',
#        'colorintensity', 'Hue', 'dilutedwines', 'Proline'],
#       dtype='object')

# %%
#Lets check the outliers

# %%
df['Proline'].plot.box()

# %%
df['MalicAcid'].plot.box()

# %%
df['Ash'].plot.box()

# %%
df['Alcalinityofash'].plot.box()

# %%
df['Magnesium'].plot.box()

# %%
#From the above we can say that their are outliers present in the data

# %%
collist=df.columns.values
ncol=14
nrows=10

# %%
plt.figure(figsize=(ncol,5*ncol))
for i in range(1,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
#To Check Skewness of the data

# %%
sns.distplot(df['Alcohol'])

# %%
sns.distplot(df['MalicAcid'])

# %%
plt.figure(figsize=(16,16))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df[collist[i]])

# %%
plt.scatter(df['Alcohol'],df['MalicAcid'])

# %%
sns.pairplot(df)

# %%
#Removing Outliers by applying zscore
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.21394365, 1.51861254, 0.5622498 , ..., 0.36217728, 1.84791957,
#         1.01300893],
#        [1.21394365, 0.24628963, 0.49941338, ..., 0.40605066, 1.1134493 ,
#         0.96524152],
#        [1.21394365, 0.19687903, 0.02123125, ..., 0.31830389, 0.78858745,
#         1.39514818],
#        ...,
#        [1.37386437, 0.33275817, 1.74474449, ..., 1.61212515, 1.48544548,
#         0.28057537],
#        [1.37386437, 0.20923168, 0.22769377, ..., 1.56825176, 1.40069891,
#         0.29649784],
#        [1.37386437, 1.39508604, 1.58316512, ..., 1.52437837, 1.42894777,
#         0.59516041]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 25,  59,  69,  73,  95, 110, 115, 121, 121, 123, 158], dtype=int64), array([ 3,  3,  5,  4,  5,  9, 11,  3,  7,  2, 10], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df
# Out:
#      Class  Alcohol  MalicAcid   Ash  Alcalinityofash  Magnesium  \
# 1        1    14.23       1.71  2.43             15.6      127.0
# 2        1    13.20       1.78  2.14             11.2      100.0
# 3        1    13.16       2.36  2.67             18.6      101.0
# 4        1    14.37       1.95  2.50             16.8      113.0
# 5        1    13.24       2.59  2.87             21.0      118.0
# ..     ...      ...        ...   ...              ...        ...
# 174      3    13.71       5.65  2.45             20.5       95.0
# 175      3    13.40       3.91  2.48             23.0      102.0
# 176      3    13.27       4.28  2.26             20.0      120.0
# 177      3    13.17       2.59  2.37             20.0      120.0
# 178      3    14.13       4.10  2.74             24.5       96.0
#
#      Totalphenols  Flavanoids  Nonflavanoidsphenols  Proanthocyanins  \
# 1            2.80        3.06                  0.28             2.29
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
df_new
# Out:
#      Class  Alcohol  MalicAcid   Ash  Alcalinityofash  Magnesium  \
# 1        1    14.23       1.71  2.43             15.6      127.0
# 2        1    13.20       1.78  2.14             11.2      100.0
# 3        1    13.16       2.36  2.67             18.6      101.0
# 4        1    14.37       1.95  2.50             16.8      113.0
# 5        1    13.24       2.59  2.87             21.0      118.0
# ..     ...      ...        ...   ...              ...        ...
# 174      3    13.71       5.65  2.45             20.5       95.0
# 175      3    13.40       3.91  2.48             23.0      102.0
# 176      3    13.27       4.28  2.26             20.0      120.0
# 177      3    13.17       2.59  2.37             20.0      120.0
# 178      3    14.13       4.10  2.74             24.5       96.0
#
#      Totalphenols  Flavanoids  Nonflavanoidsphenols  Proanthocyanins  \
# 1            2.80        3.06                  0.28             2.29
# ...

# %%
#10 rows are deleted as an outlier

# %%
df.shape
# Out:
# (178, 14)

# %%
df_new.shape
# Out:
# (168, 14)
