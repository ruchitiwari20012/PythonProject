# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

# %%
import pandas as pd
con=mysql.connector.connect(
    host="localhost",
    port=3306,
    user="root",
    password="Ruchi@1992",
    database="testdb")

df=pd.read_sql_query("select * from titanic",con)
df
df.head(10)
# Out:
#    PassengerId  Survived  Pclass        Name                             Sex  \
# 0            0         0       0        Name                             Sex
# 1            1         0       3     "Braund                Mr. Owen Harris"
# 2            2         1       1    "Cumings   Mrs. John Bradley (Florence B
# 3            3         1       3  "Heikkinen                    Miss. Laina"
# 4            4         1       1   "Futrelle   Mrs. Jacques Heath (Lily May
# 5            5         0       3      "Allen              Mr. William Henry"
# 6            6         0       3      "Moran                      Mr. James"
# 7            7         0       1   "McCarthy                  Mr. Timothy J"
# 8            8         0       3    "Palsson          Master. Gosta Leonard"
# 9            9         1       3    "Johnson   Mrs. Oscar W (Elisabeth Vilhe
#
#    Age  SibSp  Parch  Ticket      Fare    Cabin  Embarked
# 0  0.0      0      0  Ticket       0.0    Cabin  Embarked
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass        Name  \
# 0              0         0       0        Name
# 1              1         0       3     "Braund
# 2              2         1       1    "Cumings
# 3              3         1       3  "Heikkinen
# 4              4         1       1   "Futrelle
# ..           ...       ...     ...         ...
# 887          887         0       2   "Montvila
# 888          888         1       1     "Graham
# 889          889         0       3   "Johnston
# 890          890         1       1       "Behr
# 891          891         0       3     "Dooley
#
#                                 Sex  Age  SibSp  Parch  Ticket      Fare  \
# 0                               Sex  0.0      0      0  Ticket       0.0
# 1                  Mr. Owen Harris"  0.0     22      1       0       0.0
# 2     Mrs. John Bradley (Florence B  0.0     38      1       0       0.0
# 3                      Miss. Laina"  0.0     26      0       0       0.0
# ...

# %%
df.drop([0],inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass        Name  \
# 1              1         0       3     "Braund
# 2              2         1       1    "Cumings
# 3              3         1       3  "Heikkinen
# 4              4         1       1   "Futrelle
# 5              5         0       3      "Allen
# ..           ...       ...     ...         ...
# 887          887         0       2   "Montvila
# 888          888         1       1     "Graham
# 889          889         0       3   "Johnston
# 890          890         1       1       "Behr
# 891          891         0       3     "Dooley
#
#                                 Sex  Age  SibSp  Parch Ticket      Fare  \
# 1                  Mr. Owen Harris"  0.0     22      1      0       0.0
# 2     Mrs. John Bradley (Florence B  0.0     38      1      0       0.0
# 3                      Miss. Laina"  0.0     26      0      0       0.0
# 4     Mrs. Jacques Heath (Lily May   0.0     35      1      0  113803.0
# ...

# %%
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.5+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass    Age       SibSp       Parch  \
# count   891.000000  891.000000  891.000000  891.0  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.0   23.810325    0.523008
# std     257.353842    0.486592    0.836071    0.0   17.601613    1.102743
# min       1.000000    0.000000    1.000000    0.0    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    0.0    6.000000    0.000000
# 50%     446.000000    0.000000    3.000000    0.0   24.000000    0.000000
# 75%     668.500000    1.000000    3.000000    0.0   35.000000    1.000000
# max     891.000000    1.000000    3.000000    0.0   80.000000    8.000000
#
#                Fare
# count  8.910000e+02
# mean   1.931208e+05
# std    4.218167e+05
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    3.686500e+04
# 75%    3.457695e+05
# max    3.101300e+06

# %%
titanic_cleaned = df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin','Age'], axis=1)
titanic_cleaned.head()
# Out:
#    Survived  Pclass                             Sex  SibSp  Parch      Fare  \
# 1         0       3                Mr. Owen Harris"     22      1       0.0
# 2         1       1   Mrs. John Bradley (Florence B     38      1       0.0
# 3         1       3                    Miss. Laina"     26      0       0.0
# 4         1       1   Mrs. Jacques Heath (Lily May      35      1  113803.0
# 5         0       3              Mr. William Henry"     35      0  373450.0
#
#   Embarked
# 1
# 2      C85
# 3
# 4     C123
# 5

# %%
titanic_cleaned.describe()
# Out:
#          Survived      Pclass       SibSp       Parch          Fare
# count  891.000000  891.000000  891.000000  891.000000  8.910000e+02
# mean     0.383838    2.308642   23.810325    0.523008  1.931208e+05
# std      0.486592    0.836071   17.601613    1.102743  4.218167e+05
# min      0.000000    1.000000    0.000000    0.000000  0.000000e+00
# 25%      0.000000    2.000000    6.000000    0.000000  0.000000e+00
# 50%      0.000000    3.000000   24.000000    0.000000  3.686500e+04
# 75%      1.000000    3.000000   35.000000    1.000000  3.457695e+05
# max      1.000000    3.000000   80.000000    8.000000  3.101300e+06

# %%
titanic_cleanedcor=titanic_cleaned.corr()
titanic_cleanedcor
# Out:
#           Survived    Pclass     SibSp     Parch      Fare
# Survived  1.000000 -0.338481  0.010215 -0.035322 -0.101174
# Pclass   -0.338481  1.000000 -0.360975  0.083081  0.247852
# SibSp     0.010215 -0.360975  1.000000 -0.184754 -0.070161
# Parch    -0.035322  0.083081 -0.184754  1.000000  0.157004
# Fare     -0.101174  0.247852 -0.070161  0.157004  1.000000

# %%
sns.heatmap(titanic_cleanedcor)

# %%
#From the above graph it shows the negative correlation

# %%
titanic_cleaned.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Fare', 'Embarked'], dtype='object')

# %%
titanic_cleaned.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
titanic_cleaned.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
titanic_cleaned.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
sns.heatmap(titanic_cleaned.isnull())

# %%
#Their is no null values in the data

# %%
titanic_cleaned['Survived']
# Out:
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
#       ..
# 887    0
# 888    1
# 889    0
# 890    1
# 891    0
# Name: Survived, Length: 891, dtype: int64

# %%
titanic_cleaned['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
titanic_cleaned['Survived'].plot.box()

# %%
sns.countplot('Survived',data=titanic_cleaned)
plt.show()

# %%
#From the above it shows the 0 which represent female are survived more than the Male by comparing.
