# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Absenteeism_at_work.csv')

# %%
data
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
data.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#   Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
data.tail()
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 735                     289                               36            13
# 736                     235                               11            14
# 737                     118                               14            13
# 738                     231                               35            14
# 739                     179                               45            14
#
#      Age Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
data.shape
# Out:
# (740, 21)

# %%
data.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
data.dtypes
# Out:
# ID                                  int64
# Reason for absence                  int64
# Month of absence                    int64
# Day of the week                     int64
# Seasons                             int64
# Transportation expense              int64
# Distance from Residence to Work     int64
# Service time                        int64
# Age                                 int64
# Work load Average/day              object
# Hit target                          int64
# Disciplinary failure                int64
# Education                           int64
# Son                                 int64
# Social drinker                      int64
# Social smoker                       int64
# Pet                                 int64
# Weight                              int64
# Height                              int64
# Body mass index                     int64
# Absenteeism time in hours           int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
#No null value is present in the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason for absence               740 non-null    int64
#  2   Month of absence                 740 non-null    int64
#  3   Day of the week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation expense           740 non-null    int64
#  6   Distance from Residence to Work  740 non-null    int64
#  7   Service time                     740 non-null    int64
#  8   Age                              740 non-null    int64
#  9   Work load Average/day            740 non-null    object
#  10  Hit target                       740 non-null    int64
#  11  Disciplinary failure             740 non-null    int64
# ...

# %%
# I am using the Label Encoder to change the datatype of the particular columns so that i can work futher 
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Work load Average/day ']=le.fit_transform(data['Work load Average/day '])

# %%
data.dtypes
# Out:
# ID                                 int64
# Reason for absence                 int64
# Month of absence                   int64
# Day of the week                    int64
# Seasons                            int64
# Transportation expense             int64
# Distance from Residence to Work    int64
# Service time                       int64
# Age                                int64
# Work load Average/day              int32
# Hit target                         int64
# Disciplinary failure               int64
# Education                          int64
# Son                                int64
# Social drinker                     int64
# Social smoker                      int64
# Pet                                int64
# Weight                             int64
# Height                             int64
# Body mass index                    int64
# Absenteeism time in hours          int64
# dtype: object

# %%
sns.heatmap(data.isnull())

# %%
data.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# ...

# %%
#1) The mean is almost equal than the median 50th percentile in columns. 
#3)Their is large difference in 75% and max in Transportation expence ,Service time,Age,Education,Son,Pet,Weight,Absenteeism

# %%
datacor=data.corr()
datacor
# Out:
#                                        ID  Reason for absence  \
# ID                               1.000000           -0.064245
# Reason for absence              -0.064245            1.000000
# Month of absence                -0.000043           -0.083858
# Day of the week                  0.034468            0.116319
# Seasons                          0.098495           -0.117925
# Transportation expense          -0.224163           -0.119381
# Distance from Residence to Work -0.486160            0.161831
# Service time                    -0.272704            0.048425
# Age                              0.040899           -0.078608
# Work load Average/day            0.104460           -0.131877
# Hit target                       0.018789            0.088943
# Disciplinary failure             0.004502           -0.545054
# Education                       -0.036254           -0.047357
# Son                              0.002767           -0.055364
# ...

# %%
sns.heatmap(datacor)

# %%
#from the above graph i can say that their is positive correlation in Serivce time and in age,
# Positive correlation in Weight,Height and in body mass index.
# In other columns their is very less correlation.

# %%
data.groupby(['Seasons','Absenteeism time in hours']).size().unstack().plot(kind='bar',stacked=True, figsize=(30,10))

# %%
data.groupby(['Age','Absenteeism time in hours']).size().unstack().plot(kind='bar',stacked=True, figsize=(5,5))

# %%
plt.figure(figsize=(12,6))
sns.lmplot(x='Age',y='Absenteeism time in hours',data=data,hue='Day of the week',size=5,aspect=2)
# Out:
# C:\Users\Ruchi\anaconda3\lib\site-packages\seaborn\regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Most of the time,absence is present in 6th day of the week, so there are some correlation with not only age,
#but with day of week as weel

# %%
sns.jointplot(x='Transportation expense',y='Month of absence',data=data,kind='hex',color='red')

# %%
#Also here,we can see that transportation expence is bigger in winter months than in other seasons.

# %%
data['Son'].value_counts()
# Out:
# 0    298
# 1    229
# 2    156
# 4     42
# 3     15
# Name: Son, dtype: int64

# %%
#This parameter shows number of children of each worker

# %%
plt.figure(figsize=(10,5))
data[data['Son']!=0]['Absenteeism time in hours'].plot.hist(bins=30)

# %%
#In the group of people with children, absence in hours tends to be between 0 and 20,
#and very small amount was absence more than that

# %%
plt.figure(figsize=(10,6))
data[data['Son']==0]["Absenteeism time in hours"].plot.hist(bins=30)

# %%
#This graph show number of people without any children, so we can see, the top time is around 60 hours,
#which is less, than those people with children

# %%
g=sns.FacetGrid(data=data,col='Son')
g.map(plt.hist,'Absenteeism time in hours')

# %% [markdown]
# Here all possible options for 'Son' column are shown in their correlation with absence time.We can see that,if you have
# 1 or 2 children,it is more likely to be absent at work.Prbably,beacause if you only 1 child and a mother presumably,
# noone can sit with child,apart from you and your spouse.But, if we look further,more children you have,less time you are
# absent.It means,that they can basically watch each othr, and you dont need to stay home to take care of them.

# %%
plt.figure(figsize=(14,6))
data[data['Son']==0]['Age'].plot.hist(bins=30)

# %%
plt.figure(figsize=(14,6))
data[data['Son']!=0]['Age'].plot.hist(bins=30)

# %% [markdown]
# Also here we can see that people without children mostly around 35 and 40.And obviously, some young people.
# and distribution of age vs children in the family

# %%
plt.figure(figsize=(10,5))
sns.distplot(data['Reason for absence'])

# %%
data[data['Reason for absence']==27].count()
# Out:
# ID                                 69
# Reason for absence                 69
# Month of absence                   69
# Day of the week                    69
# Seasons                            69
# Transportation expense             69
# Distance from Residence to Work    69
# Service time                       69
# Age                                69
# Work load Average/day              69
# Hit target                         69
# Disciplinary failure               69
# Education                          69
# Son                                69
# Social drinker                     69
# Social smoker                      69
# Pet                                69
# Weight                             69
# Height                             69
# Body mass index                    69
# Absenteeism time in hours          69
# dtype: int64

# %% [markdown]
# Reason 27 is according to attributes is physiotherapy (27). So some amount of people are suffering from workload,
# possibly to make up time they spend at home with children

# %%
data[data['Absenteeism time in hours']==0].count()
# Out:
# ID                                 44
# Reason for absence                 44
# Month of absence                   44
# Day of the week                    44
# Seasons                            44
# Transportation expense             44
# Distance from Residence to Work    44
# Service time                       44
# Age                                44
# Work load Average/day              44
# Hit target                         44
# Disciplinary failure               44
# Education                          44
# Son                                44
# Social drinker                     44
# Social smoker                      44
# Pet                                44
# Weight                             44
# Height                             44
# Body mass index                    44
# Absenteeism time in hours          44
# dtype: int64

# %%
# Only 44/740 = 0.60% workers have never been absent from work

# %%
df=data.groupby('Reason for absence')

# %%
df['Absenteeism time in hours'].max()
# Out:
# Reason for absence
# 0       0
# 1      64
# 2      24
# 3       8
# 4       8
# 5       8
# 6     120
# 7      40
# 8       8
# 9     112
# 10     48
# 11    120
# 12    112
# 13    120
# 14     40
# 15      8
# 16      3
# 17      8
# 18     80
# 19    104
# 21      8
# 22     16
# 23     16
# 24      8
# 25      8
# 26     16
# 27      3
# 28     24
# Name: Absenteeism time in hours, dtype: int64

# %% [markdown]
# 6.VI Diseases of the nervous system.
# 9.IX Diseases of the circulatory system.
# 11.XI Diseases of the skin and subcutaneous tissue.
# 13.XIII Disease of musculokeletal system and connective tissue.
# 19.XIX Injury,poisoning and certain other consequences of external causes
#
# These are top reasons for absence

# %%
data.skew()
# Out:
# ID                                 0.016606
# Reason for absence                -0.915312
# Month of absence                   0.069369
# Day of the week                    0.102440
# Seasons                           -0.038532
# Transportation expense             0.396189
# Distance from Residence to Work    0.312083
# Service time                      -0.004720
# Age                                0.697703
# Work load Average/day              0.050294
# Hit target                        -1.261708
# Disciplinary failure               3.952270
# Education                          2.108953
# Son                                1.086465
# Social drinker                    -0.273327
# Social smoker                      3.290333
# Pet                                2.735715
# Weight                             0.017001
# Height                             2.566060
# Body mass index                    0.305046
# Absenteeism time in hours          5.720728
# dtype: float64

# %%
# Treating using log
import numpy as np
for col in data.columns:
    if data.skew().loc[col]>0.55:
        data[col]=np.log1p(data[col])

# %% [markdown]
# Lets check again the skewness

# %%
data.skew()
# Out:
# ID                                 0.016606
# Reason for absence                -0.915312
# Month of absence                   0.069369
# Day of the week                    0.102440
# Seasons                           -0.038532
# Transportation expense             0.396189
# Distance from Residence to Work    0.312083
# Service time                      -0.004720
# Age                                0.268628
# Work load Average/day              0.050294
# Hit target                        -1.261708
# Disciplinary failure               3.952270
# Education                          1.968323
# Son                                0.254626
# Social drinker                    -0.273327
# Social smoker                      3.290333
# Pet                                1.192919
# Weight                             0.017001
# Height                             2.429570
# Body mass index                    0.305046
# Absenteeism time in hours          0.749686
# dtype: float64

# %%
#Lets check pairplot using seaborn library
import seaborn as sns
sns.pairplot(data)
plt.show()

# %%
#Lets check for outliers
from scipy.stats import zscore
z_score=abs(zscore(data))
print(data.shape)
data_final=data.loc[(z_score<3).all(axis=1)]
print(data_final.shape)
# Out:
# (740, 21)
# (584, 21)

# %%
#so from the data the 156 outliers are removed

# %%
# Separating target and input variables
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(data_final)
x=pd.DataFrame(x,columns=data_final.columns)

# %%
x
x.head()
# Out:
#          ID  Reason for absence  Month of absence  Day of the week   Seasons  \
# 0 -0.626881            0.730258          0.206828        -0.655638 -1.402915
# 1 -1.326878            0.312422          0.206828         0.045631 -1.402915
# 2 -0.626881            0.312422          0.206828         0.746899 -1.402915
# 3 -1.326878            0.312422          0.206828         1.448168 -1.402915
# 4 -0.714380            0.173144          0.206828         1.448168 -1.402915
#
#    Transportation expense  Distance from Residence to Work  Service time  \
# 0                1.022465                         0.349882      0.177222
# 1               -0.653724                         1.364434      1.383486
# 2                1.022465                         0.349882      0.177222
# 3               -0.653724                         1.364434      1.383486
# 4                2.119606                         1.432071     -2.235306
#
# ...

# %%
y=data_final.iloc[:,-1]
y.head()
# Out:
# 0    1.609438
# 2    1.098612
# 4    1.098612
# 5    1.098612
# 6    2.197225
# Name: Absenteeism time in hours, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(y)
y
# Out:
# array([ 4,  2,  2,  2,  7,  4,  7,  7,  7,  7,  1,  4,  7,  2,  7,  7,  2,
#         7,  1, 11,  4,  7,  6,  1,  7,  2,  7,  4,  2,  1,  7,  4,  4,  2,
#         4,  4,  7,  3,  3,  4,  7, 10,  2,  2,  3,  3,  1,  3,  4,  3,  3,
#         1,  3,  3,  3,  2,  2,  5,  7,  3,  8,  7,  2,  7,  1,  3,  1,  1,
#         7,  5,  7, 11,  1,  3,  3,  4,  1,  3,  9,  3,  1,  2,  7,  2,  7,
#        12,  7,  3,  3,  2,  7,  2,  7,  2,  1,  1,  1,  2,  2,  2,  1,  2,
#         2,  2,  2,  2,  2,  2,  2,  7,  7,  2,  2,  2,  0,  1,  3,  1,  7,
#         7,  7,  2,  7,  7,  7,  2,  2,  1,  7,  3,  7,  1,  1,  7,  2,  7,
#         7,  7,  7,  3, 11,  8,  7,  4,  1,  9,  2,  7,  1,  7,  8,  3,  2,
#         3,  1,  1,  1,  9,  2,  4,  9,  1,  3,  7,  1,  7, 12,  7,  8,  3,
#         7,  7,  7,  4,  1,  9,  1,  9,  7,  7,  7,  9,  4,  7,  7,  7,  7,
#         8,  1,  2,  2,  7,  7,  4,  7,  7,  7,  7,  7,  7,  7, 10,  7,  7,
# ...

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corressponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
#Lets use Linear regression and check max r2 score corressponding to different random state
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
r_state=maxr2_score(lreg,x,y)
# Out:
# r2 score corresponding to  42  is  0.96908993503063
# r2 score corresponding to  43  is  0.9672857794376748
# r2 score corresponding to  44  is  0.9575787897085861
# r2 score corresponding to  45  is  0.9665696840658576
# r2 score corresponding to  46  is  0.961677792635548
# r2 score corresponding to  47  is  0.9652415783660949
# r2 score corresponding to  48  is  0.9686523711743831
# r2 score corresponding to  49  is  0.9680068150191685
# r2 score corresponding to  50  is  0.962896255156351
# r2 score corresponding to  51  is  0.9691456014854101
# r2 score corresponding to  52  is  0.963751499814936
# r2 score corresponding to  53  is  0.9628404928218662
# r2 score corresponding to  54  is  0.9649971368663726
# r2 score corresponding to  55  is  0.9626999934483013
# r2 score corresponding to  56  is  0.9668333651777353
# r2 score corresponding to  57  is  0.9668764911267048
# r2 score corresponding to  58  is  0.9598149227590806
# ...

# %%
#Lets use grid_search to find optimal value of n_neigbors for KNN model
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,30)}
knr=KNeighborsRegressor()
gknr = GridSearchCV(knr,neighbors, cv=5)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 4}

# %%
#Lets use KNN regression and check max r2 score corresponding to different random states
knr=KNeighborsRegressor(n_neighbors=4)
r_state=maxr2_score(knr,x,y)
# Out:
# r2 score corresponding to  42  is  0.5806718255806926
# r2 score corresponding to  43  is  0.576864565026362
# r2 score corresponding to  44  is  0.5670719103026438
# r2 score corresponding to  45  is  0.44622957992998846
# r2 score corresponding to  46  is  0.6246055123080161
# r2 score corresponding to  47  is  0.6715947855750486
# r2 score corresponding to  48  is  0.6929688464069763
# r2 score corresponding to  49  is  0.6608490144212666
# r2 score corresponding to  50  is  0.6380871077118693
# r2 score corresponding to  51  is  0.5090583471760798
# r2 score corresponding to  52  is  0.6531700045004502
# r2 score corresponding to  53  is  0.5588542742102003
# r2 score corresponding to  54  is  0.60793618625428
# r2 score corresponding to  55  is  0.6698152130426086
# r2 score corresponding to  56  is  0.6796309361337928
# r2 score corresponding to  57  is  0.5591614053349416
# r2 score corresponding to  58  is  0.596815725066286
# ...

# %%
#Lets check the mean r2 score of both LinearRegression model and knn regression
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Linear Regression :",cross_val_score(lreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Linear Regression:",cross_val_score(lreg,x,y,cv=5,scoring="r2").std())
print()
print("Mean r2 score for KNN Regression:",cross_val_score(knr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for KNN Regression: ",cross_val_score(knr,x,y,cv=5,scoring="r2").std())
#Based on below output Linear Regression is performing well
# Out:
# Mean r2 score for Linear Regression : 0.9627699361316372
# standard deviation in r2 score for Linear Regression: 0.005255880144736737
#
# Mean r2 score for KNN Regression: 0.5813365456646926
# standard deviation in r2 score for KNN Regression:  0.0289864905321088

# %%
#Lets check laso Regression and find best value of alpha
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf = GridSearchCV(lsreg, parameters, cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.01}

# %%
#Lets check max_r2 score whenwe use lasso
lsreg=Lasso(alpha=0.01)
r_stat=maxr2_score(lsreg,x,y)
# Out:
# r2 score corresponding to  42  is  0.9698481367170841
# r2 score corresponding to  43  is  0.9678303589872428
# r2 score corresponding to  44  is  0.9580831196403234
# r2 score corresponding to  45  is  0.9674798453445849
# r2 score corresponding to  46  is  0.9621941900177929
# r2 score corresponding to  47  is  0.9641441248740323
# r2 score corresponding to  48  is  0.9688096437523588
# r2 score corresponding to  49  is  0.9676016234985453
# r2 score corresponding to  50  is  0.9627105782807401
# r2 score corresponding to  51  is  0.9700890073671081
# r2 score corresponding to  52  is  0.9627731585332054
# r2 score corresponding to  53  is  0.9628441064817906
# r2 score corresponding to  54  is  0.9667399569435469
# r2 score corresponding to  55  is  0.9625629605002118
# r2 score corresponding to  56  is  0.9672277310843042
# r2 score corresponding to  57  is  0.9678323991896209
# r2 score corresponding to  58  is  0.9607061839141493
# ...

# %%
#Lets use cross val score with lasso
print("Mean r2_score for Lasso Regression: ",cross_val_score(lsreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Lasso Regression: ",cross_val_score(lsreg,x,y,cv=5,scoring="r2").std())
#Based on below output i can say lasso performed just like linear regression
# Out:
# Mean r2_score for Lasso Regression:  0.9639876844730997
# standard deviation in r2 score for Lasso Regression:  0.004301147277063635

# %%
#Now we will try to use gradient boosting technique
#for getting best set of parameters we will use grid search
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000,]}
clr = GridSearchCV(gbr, parameters, cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.01}

# %%
#Now we will use cross val score to check the mean r2 score and standard deviation
gbr=GradientBoostingRegressor(learning_rate=0.01,n_estimators=500)
print("Mean r2 score for gradiant boosting Regression: ",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for gradient boosting Regression: ",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for gradiant boosting Regression:  0.9995841434061704
# standard deviation in r2 score for gradient boosting Regression:  0.0007580263237939818

# %%
#Lets check maximum r2_score corresponding to this
r_state=maxr2_score(gbr,x,y)
# Out:
# r2 score corresponding to  42  is  0.9999531140262501
# r2 score corresponding to  43  is  0.9999448631607948
# r2 score corresponding to  44  is  0.9963129165182446
# r2 score corresponding to  45  is  0.9999529985267244
# r2 score corresponding to  46  is  0.9999537313202134
# r2 score corresponding to  47  is  0.9966468581878712
# r2 score corresponding to  48  is  0.9999347931959054
# r2 score corresponding to  49  is  0.9983919103538185
# r2 score corresponding to  50  is  0.9982495347534774
# r2 score corresponding to  51  is  0.9999334424496056
# r2 score corresponding to  52  is  0.9992121366689538
# r2 score corresponding to  53  is  0.9994256876981087
# r2 score corresponding to  54  is  0.9999384915987556
# r2 score corresponding to  55  is  0.9999531306281066
# r2 score corresponding to  56  is  0.9999547020751961
# r2 score corresponding to  57  is  0.9999430950074055
# r2 score corresponding to  58  is  0.9999477743401249
# ...

# %%
#Now lets use the ada boost regression algorithm
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lreg,lsreg,DecisionTreeRegressor()]}
clf = GridSearchCV(ada_reg, parameters, cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best'),
#  'learning_rate': 0.01,
#  'n_estimators': 500}

# %%
ada_reg=AdaBoostRegressor(base_estimator=lsreg,learning_rate=0.001,n_estimators=10)
print("Mean r2 score for ada boosting Regression: ",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for ada boosting Regression: ",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for ada boosting Regression:  0.964012174218054
# standard deviation in r2 score for ada boosting Regression:  0.004714229882788264

# %%
#Lets check maximum r2_score corresponding to this
r_state=maxr2_score(ada_reg,x,y)
# Out:
# r2 score corresponding to  42  is  0.9702061186736405
# r2 score corresponding to  43  is  0.9673300318288961
# r2 score corresponding to  44  is  0.958490826618809
# r2 score corresponding to  45  is  0.9672121621471422
# r2 score corresponding to  46  is  0.9608388496706852
# r2 score corresponding to  47  is  0.9646261924142568
# r2 score corresponding to  48  is  0.9685029342054289
# r2 score corresponding to  49  is  0.9668512785631802
# r2 score corresponding to  50  is  0.962871380742234
# r2 score corresponding to  51  is  0.9691129194018849
# r2 score corresponding to  52  is  0.9633246462752102
# r2 score corresponding to  53  is  0.9626535454910556
# r2 score corresponding to  54  is  0.9667561103456263
# r2 score corresponding to  55  is  0.9633618466563405
# r2 score corresponding to  56  is  0.9669933020016247
# r2 score corresponding to  57  is  0.9682504737780182
# r2 score corresponding to  58  is  0.9605883003720788
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = 61,test_size=0.20)
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
y_pred=gbr.predict(x_test)

# %%
#Lets find the rmse and r2_score using sklearn,metrics 
import numpy as np
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error 
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score is: ",r2_score(y_test,y_pred))
# Out:
# RMSE is:  0.0051338447202819715
# r2_score is:  0.9999961387817412

# %%
from sklearn.externals import joblib

#save the model as a pickel in a file
joblib.dump(gbr, "Absenteeism_gbr.pkl")
# Out:
# ['Absenteeism_gbr.pkl']

# %% [markdown]
# Conclusion : In this dataset firstly i look the data since i have to predict the Absenteeism time in hours  so i take it as a Y variable and rest column was taken as a X before spliting the dataset i check the datatype and change the datatype of the columns and see the correlation , null values , description, skewness and pairplot i check the outlier 156 outliers got removed.Than i split the data into x and y and apply the standard scaler in x and in y the label encoder.
#
# You will see that in LinearRegression r2 score of 99 is 00.97 In KNeighborsRegression r2 score of 71 is 0.72 In GradientBoostingRegressor r2 score of  56 is 0.99 In Lasso r2 score corressponding to 99 is 0.97. Since from the 4 algorithm i see that I am getting best score in GradientBoostingRegressor So i am saving the model.
